# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmielnik/AER850-Project-3/blob/main/AER850Project3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.7/898.7 kB 25.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import cv2
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

dataset = '/content/drive/MyDrive/datasets/data.yaml'


# Load a model
model = YOLO("yolov8n.pt")

# Train the model with cuda
results = model.train(data=dataset, epochs=120, batch=8, imgsz=992, device='cuda')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 118MB/s]
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.49 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,008,183 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1_UAgUkKWdyT2wUsY7DZCW7MGvduKD1gR/datasets/valid/labels.cache... 105 images, 0 backgrounds, 0 corrupt: 100%|██████████| 105/105 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 26, len(boxes) = 19108. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:16<00:00,  1.16s/it]
#                    all        105      19108      0.818      0.653      0.726      0.532
#                 Button         14         45      0.961      0.978       0.99      0.828
# ...

# %%
results = model.predict(source="/content/drive/MyDrive/datasets/evaluation", save=True)
# Out:
# image 1/3 /content/drive/MyDrive/datasets/evaluation/ardmega.jpg: 896x992 1 Button, 11 Capacitors, 10 Connectors, 2 Electrolytic Capacitors, 8 ICs, 3 Leds, 1 Pads, 21 Resistors, 72.7ms
# image 2/3 /content/drive/MyDrive/datasets/evaluation/arduno.jpg: 672x992 19 Capacitors, 10 Connectors, 3 Electrolytic Capacitors, 5 ICs, 3 Leds, 8 Resistors, 1 Transistor, 33.2ms
# image 3/3 /content/drive/MyDrive/datasets/evaluation/rasppi.jpg: 672x992 20 Capacitors, 11 Connectors, 1 Diode, 1 Electrolytic Capacitor, 10 ICs, 2 Leds, 2 Padss, 15 Resistors, 10.8ms
# Speed: 6.6ms preprocess, 38.9ms inference, 4.1ms postprocess per image at shape (1, 3, 672, 992)
# Results saved to runs/detect/train3

# %%
# Iterate through results and adjust label font size
i = 0
for r in results:
    i += 1
    im_array = r.plot(line_width=5, font_size=1)
    im = Image.fromarray(im_array[..., ::-1])
    im.show()
    im.save(f"/content/runs/detect/image_{i}.jpg")
    plt.imshow(im)
    plt.axis('off')
    plt.show()
